# %% [markdown]
# # PREPROCESSING

# %%
import pandas as pd
import numpy as np
from sklearn import neighbors as nei
from sklearn import metrics as met

# %%
data = pd.read_csv("train.csv")
data.head()
# Out:
#    userID  movieID  rating
# 0    4490     2109       4
# 1    5839     3471       4
# 2    5382      150       3
# 3    1262     1237       5
# 4    6005     2273       4

# %%
data.describe()
# Out:
#               userID       movieID         rating
# count  990209.000000  990209.00000  990209.000000
# mean     3016.430061    1865.56350       3.581463
# std      1728.237347    1096.00108       1.117173
# min         1.000000       1.00000       1.000000
# 25%      1565.000000    1030.00000       3.000000
# 50%      2970.000000    1835.00000       4.000000
# 75%      4535.000000    2770.00000       4.000000
# max      6040.000000    3952.00000       5.000000

# %%
u=data.rating.mean()

# %%
U = data.pivot("movieID", "userID", "rating")
U.head()
# Out:
# userID   1     2     3     4     5     6     ...  6035  6036  6037  6038  6039  6040
# movieID                                      ...
# 1         3.0   NaN   NaN   NaN   NaN   4.0  ...   4.0   NaN   NaN   NaN   NaN   5.0
# 2         NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN   1.0  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN   2.0  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 5         NaN   NaN   NaN   NaN   NaN   1.0  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 6040 columns]

# %%
Z = data.pivot("userID", "movieID", "rating")
Z.head()
# Out:
# movieID  1     2     3     4     5     6     ...  3947  3948  3949  3950  3951  3952
# userID                                       ...
# 1         3.0   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 2         NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3         NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 4         NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 5         NaN   NaN   NaN   NaN   NaN   3.0  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 3705 columns]

# %%
U.shape
# Out:
# (3705, 6040)

# %%
train_size = 3670
train = U[:train_size]
test = U[train_size:]

# %%
test
# Out:
# userID   1     2     3     4     5     6     ...  6035  6036  6037  6038  6039  6040
# movieID                                      ...
# 3918      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3919      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3920      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3921      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3922      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3923      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3924      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3925      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3926      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3927      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3928      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3929      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3930      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3931      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3932      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3933      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3934      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3935      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3936      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3937      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3938      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3939      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3940      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3941      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3942      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3943      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3944      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3945      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3946      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3947      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3948      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3949      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3950      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3951      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
# 3952      NaN   NaN   NaN   NaN   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN   NaN
#
# [35 rows x 6040 columns]

# %% [markdown]
# **I did create a data for item  to item predection as it is better than user to user to use on global baseline approach and I also did create a small test to see if my model is working and my rmse results for this pairs(not best test approach but still usable for me to see if there is any problem)**

# %% [markdown]
# # Global Baseline Method

# %%
myPreds = []
realLabels = []
for movieID in test.index:
 for userID in test.columns:
    if not np.isnan(test.loc[movieID, userID]):
      filtered_train = train.dropna(subset=[userID])
      filtered_train = filtered_train - filtered_train.mean(axis=1).values.reshape(-1,1)
      filtered_train.fillna(0, inplace=True)
      if 20 < len(filtered_train):
        k=20
        nn = nei.NearestNeighbors(n_neighbors=k, metric='cosine')
        nn.fit(filtered_train)
        test_row = test.loc[movieID:movieID, :]
        test_row = test_row - test_row.mean(axis=1).values.reshape(-1,1)
        test_row.fillna(0, inplace=True)
        indices = nn.kneighbors(test_row, return_distance=False)[0]
        movieIds = filtered_train.iloc[indices, :].index
        pred = filtered_train.loc[movieIds, userID].values.mean()
        bx=U[userID].mean()-u
        bi=Z[movieID].mean()-u
        x=bi+bx+u
        pred=pred+x
        if pred>5:
          pred=5
        if pred<1:
          pred=1  
        myPreds.append(pred)
        real_label = test.loc[movieID, userID]
        realLabels.append(real_label)  
      else:
        k=len(filtered_train)
        if k==0:
          pred=u
        else:
         k=len(filtered_train)  
         nn = nei.NearestNeighbors(n_neighbors=k, metric='cosine')
         nn.fit(filtered_train)
         test_row = test.loc[movieID:movieID, :]
         test_row = test_row - test_row.mean(axis=1).values.reshape(-1,1)
         test_row.fillna(0, inplace=True)
         indices = nn.kneighbors(test_row, return_distance=False)[0]
         movieIds = filtered_train.iloc[indices, :].index
         pred = filtered_train.loc[movieIds, userID].values.mean()
         bx=U[userID].mean()-u
         bi=Z[movieID].mean()-u
         x=bi+bx+u
         pred=pred+x
         if pred>5:
          pred=5
         if pred<1:
          pred=1    
        myPreds.append(pred)
        real_label = test.loc[movieID, userID]
        realLabels.append(real_label)

# %%
met.mean_squared_error(realLabels, myPreds, squared=False)
# Out:
# 0.8905363860180417

# %% [markdown]
# **I did make predictions for 4358  pairs and my rmse 0.89 and it is worse than item to item aproach for same test**

# %% [markdown]
# # CREATING KAGGLE SUBMISSION

# %%
test = pd.read_csv("test_without_labels.csv")

# %%
myPreds = []
for i in test.IDs:
  a = i.split("_")
  userID=int(a[0])
  movieID=int(a[1])
  filtered_train = U.dropna(subset=[userID])
  filtered_train = filtered_train - filtered_train.mean(axis=1).values.reshape(-1,1)
  filtered_train.fillna(0, inplace=True)
  if 20 < len(filtered_train):
        k=20
        nn = nei.NearestNeighbors(n_neighbors=k, metric='cosine')
        nn.fit(filtered_train)
        test_row = U.loc[movieID:movieID, :]
        test_row = test_row - test_row.mean(axis=1).values.reshape(-1,1)
        test_row.fillna(0, inplace=True)
        indices = nn.kneighbors(test_row, return_distance=False)[0]
        movieIds = filtered_train.iloc[indices, :].index
        pred = filtered_train.loc[movieIds,userID ].values.mean()
        bx=U[userID].mean()-u
        bi=Z[movieID].mean()-u
        x=bi+bx+u
        pred=pred+x
        if pred>5:
          pred=5
        myPreds.append(pred)
  else:
        k=len(filtered_train)
        if k==0:
          pred=u
        else:
         k=len(filtered_train)  
         nn = nei.NearestNeighbors(n_neighbors=k, metric='cosine')
         nn.fit(filtered_train)
         test_row = U.loc[movieID:movieID, :]
         test_row = test_row - test_row.mean(axis=1).values.reshape(-1,1)
         test_row.fillna(0, inplace=True)
         indices = nn.kneighbors(test_row, return_distance=False)[0]
         movieIds = filtered_train.iloc[indices, :].index
         pred = filtered_train.loc[movieIds,userID ].values.mean()
         bx=U[userID].mean()-u
         bi=Z[movieID].mean()-u
         x=bi+bx+u
         pred=pred+x
         if pred>5:
          pred=5  
        myPreds.append(pred)

# %%
myPreds_num=[]

# %%
for i in myPreds:
  i=float(i)
  myPreds_num.append(i)

# %%
test["rating"]=myPreds_num

# %%
test.head()
# Out:
#          IDs    rating
# 0   629_2683  3.684545
# 1    601_904  5.000000
# 2  5673_3717  3.347750
# 3  5616_1721  3.391924
# 4  1099_3697  2.954757

# %%
test["rating"]=myPreds_num
dfpred = pd.DataFrame(test, columns = ['IDs', "rating"])
dfpred.to_csv("output.xlsx",index=False)

# %% [markdown]
# **My result for caggle is 0.95221  it is worse than item to item and user to user**
